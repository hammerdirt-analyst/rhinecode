# %%
# sys things
import os
import sys
import json
import os

# networks
import requests

# data
import pandas as pd
import numpy as np
import scipy
import math
import seaborn as sns

# %%
import resources.utilities.utility_functions as ut

# %%
a, b, c, d, e =ut.make_local_paths()

# %%
print(a,b,c,d,e)
# Out:
# resources\surveydata resources\locationdata resources\mlwcodedefs resources\geodata output

# %%
pd.read_csv(a+'/OSPAR_ID_DutchEnglish.csv')
# Out:
#                                                ID  \
# 0                            plastic_6_packringen
# 1                                  plastic_tassen
# 2                   plastic_kleine_plastic_tasjes
# 3       plastic_drankflessen_groterdan_halveliter
# 4      plastic_drankflessen_kleinerdan_halveliter
# 5                plastic_wikkels_van_drankflessen
# 6       plastic_verpakking_van_schoonmaakmiddelen
# 7     plastic_voedselverpakkingen_frietbakjes_etc
# 8                   plastic_cosmeticaverpakkingen
# 9       plastic_motorolieverpakking_groterdan50cm
# 10                              plastic_jerrycans
# 11                                plastic_kratten
# 12                        plastic_auto_onderdelen
# 13                      plastic_doppen_en_deksels
# 14                             plastic_aanstekers
# 15                              plastic_speelgoed
# 16        plastic_plastic_bekers_of_delen_daarvan
# 17                              plastic_netzakken
# 18             plastic_handschoenen_huishoudelijk
# 19             plastic_handschoenen_professioneel
# 20            plastic_touw_diameter_groterdan_1cm
# 21           plastic_touw_diameter_kleinerdan_1cm
# 22                        plastic_sportvisspullen
# 23                          plastic_breekstaafjes
# 24                                 plastic_emmers
# 25       plastic_industrieel_verpakkingsmateriaal
# 26                                 plastic_helmen
# 27                         plastic_geweerpatronen
# 28                               plastic_schoenen
# 29   plastic_plastic_stukjes_0_2_5cm_hard_plastic
# ..                                            ...
# 82                     metaal_elektriciteitsdraad
# 83                               metaal_oud_ijzer
# 84                             metaal_kroonkurken
# 85                                metaal_oliedrum
# 86             metaal_omheinigsdraad_prikkeldraad
# 87                             metaal_spuitbussen
# 88                                metaal_verfblik
# 89                                 metaal_vislood
# 90                          metaal_voedselblikken
# 91                        metaal_wegwerpbarbecues
# 92           metaal_overig_metaal_kleinerdan_50cm
# 93            metaal_overig_metaal_groterdan_50cm
# 94                           glas_flessen_pottten
# 95                          glas_lampen_tl_lampen
# 96                               glas_overig_glas
# 97                             sanitair_cosmetica
# 98                sanitair_plastic_wattenstaafjes
# 99              sanitair_kartonnen_wattenstaafjes
# 100                     sanitair_vochtige_doekjes
# 101                             sanitair_condooms
# 102   sanitair_maandverband_en_verpakkingen_ervan
# 103                  sanitair_plastic_kam_borstel
# 104         sanitair_tampons_en_tamponapplicators
# 105                    sanitair_tissues_wc_papier
# 106                    sanitair_toiletverfrissers
# 107                      sanitair_overig_sanitair
# 108                          medisch_verpakkingen
# 109                               medisch_spuiten
# 110                        medisch_overig_medisch
# 111                             granulaat_korrels
#
#                         Description       category  OSPAR_ID
# 0                     Six pack ring        PO soft     1.000
# 1                               Bag        PO soft     2.000
# 2                         Small bag        PO soft     3.000
# 3                 Bottle (>= 0.5 L)            PET     4.100
# 4                  Bottle (< 0.5 L)            PET     4.200
# 5                      Bottle label        PO soft     4.300
# 6        Cleaning product packaging        PO hard     5.000
# 7                    Food packaging    Polystyrene     6.000
# 8               Cosmetics packaging        PO hard     7.000
# 9    Motor oil packaging (>= 50 cm)        PO hard     9.000
# 10                         Jerrycan        PO hard    10.000
# 11                            Crate        PO hard    13.000
# 12                        Car parts        PO hard    14.000
# 13                    Caps and lids    Polystyrene    15.000
# 14                          Lighter        PO hard    16.000
# 15                              Toy    Polystyrene    20.000
# 16                              Cup    Polystyrene    21.000
# 17                          Net bag        PO soft    24.000
# 18                   Cleaning glove        PO soft    25.000
# 19                            Glove        PO soft   113.000
# 20                             Rope        PO soft    31.000
# 21                             Rope        PO soft    32.000
# 22                        Fish gear        PO soft    33.000
# 23                        Glowstick        PO hard    36.000
# 24                           Bucket        PO hard    38.000
# 25             Industrial packaging        PO soft    40.000
# 26                           Helmet        PO hard    42.000
# 27                       Gun rounds        PO hard    43.000
# 28                             Shoe        PO hard    44.000
# 29           Hard fragment (< 5 cm)        PO hard   117.100
# ..                              ...            ...       ...
# 82                  Electrical wire     No plastic    79.000
# 83                        Iron part     No plastic    83.000
# 84                 Metal bottle cap     No plastic    77.000
# 85                         Oil drum     No plastic    84.000
# 86                      Barbed wire     No plastic    88.000
# 87                        Spray can     No plastic    76.000
# 88                        Paint can     No plastic    86.000
# 89                        Fish lead     No plastic    80.000
# 90                         Food can     No plastic    82.000
# 91                 Single use grill     No plastic   120.000
# 92            Other metal (< 50 cm)     No plastic    89.000
# 93           Other metal (>= 50 cm)     No plastic    90.000
# 94                              Pot     No plastic    91.000
# 95                        Tube lamp     No plastic    92.000
# 96                      Other glass     No plastic    93.000
# 97                        Cosmetics     No plastic     7.000
# 98                      Cotton swab        PO hard    98.000
# 99               Carton cotton swab     No plastic   982.000
# 100                      Wet tissue     No plastic   102.200
# 101                          Condom     No plastic    97.000
# 102                  Sanitary towel     No plastic    99.000
# 103                      Hair brush        PO hard    18.000
# 104             Tampon (applicator)     No plastic   100.000
# 105                    Toilet paper     No plastic   102.300
# 106                Toilet refresher        PO hard   101.000
# 107                  Other sanitary     No plastic   102.000
# 108               Medical packaging     Multilayer   103.000
# 109                         Syringe     No plastic   104.000
# 110                   Other medical     No plastic   105.000
# 111                          Nurdle  Other plastic     1.172
#
# [112 rows x 4 columns]

# %%
pd.read_csv(a+'/mlw_codes.csv')
# Out:
#      code      material                                        description  \
# 0    G212     Chemicals    Oil nodules or coal fragments -- not from a BBQ
# 1    G213     Chemicals                                       Paraffin wax
# 2    G214     Chemicals                                            Oil/tar
# 3    G135         Cloth                Clothes, footware, headware, gloves
# 4    G136         Cloth                                              Shoes
# 5    G137         Cloth                            Clothing, towels & rags
# 6    G138         Cloth                                  Shoes and sandals
# 7    G139         Cloth                                          Backpacks
# 8    G140         Cloth                Bags, burlap, hessian, jute or hemp
# 9    G141         Cloth                                             Carpet
# 10   G142         Cloth                              Rope , string or nets
# 11   G143         Cloth                                   Sails and canvas
# 12   G144         Cloth                                            Tampons
# 13   G145         Cloth                                     Other textiles
# 14   G902         Cloth                       Mask medical, cloth reusable
# 15   G200         Glass             Glass or ceramic drink bottles, pieces
# 16   G201         Glass            Jars, glass or pottery, includes pieces
# 17   G202         Glass                                        Light bulbs
# 18   G203         Glass   Tableware ceramic or glass, cups, plates, pieces
# 19   G204         Glass       Construction material; bricks, pipes, cement
# 20   G205         Glass                            Fluorescent light tubes
# 21   G206         Glass                                        Glass buoys
# 22   G207         Glass                                       Octopus pots
# 23   G208         Glass                Glass or ceramic fragments > 2.5 cm
# 24   G209         Glass                                Large glass objects
# 25   G210         Glass                                Other glass/ceramic
# 26   G917         Glass                                   Terracotta balls
# 27   G921         Glass                            Ceramic tile and pieces
# 28   G174         Metal                                 Aerosol spray cans
# 29   G175         Metal                                     Cans, beverage
# ..    ...           ...                                                ...
# 230  G125        Rubber                        Balloons and balloon sticks
# 231  G126        Rubber                                              Balls
# 232  G127        Rubber                                       Rubber boots
# 233  G128        Rubber                                    Tires and belts
# 234  G129        Rubber                      Inner tubes and rubber sheets
# 235  G130        Rubber                                             Wheels
# 236  G131        Rubber                                       Rubber bands
# 237  G132        Rubber                                  Bobbers (fishing)
# 238  G133        Rubber                            Condoms incl. packaging
# 239  G134        Rubber                                       Other rubber
# 240  G900        Rubber        Gloves latex  personal protective equipment
# 241  G998     Undefined                               No exposed shoreline
# 242  G211  Unidentified  Other medical items (swabs, bandaging, adhesiv...
# 243  G999  Unidentified                    No objects found on this survey
# 244  G159          Wood                                              Corks
# 245  G160          Wood                                            Pallets
# 246  G161          Wood                                   Processed timber
# 247  G162          Wood                                             Crates
# 248  G163          Wood                                  Crab lobster pots
# 249  G164          Wood                                         Fish boxes
# 250  G165          Wood           Ice cream sticks, toothpicks, chopsticks
# 251  G166          Wood                                      Paint brushes
# 252  G167          Wood                               Matches or fireworks
# 253  G168          Wood                                        Wood boards
# 254  G169          Wood                                     Beams, dunnage
# 255  G170          Wood                                   Wood (processed)
# 256  G171          Wood                                  Other wood < 50cm
# 257  G172          Wood                                  Other wood > 50cm
# 258  G173          Wood                                              Other
# 259  G916          Wood                                 Pencils and pieces
#
#                       source               source_two  \
# 0                  Undefined  Where does it come from
# 1                  Undefined  Where does it come from
# 2               Construction  Where does it come from
# 3                   Clothing  Where does it come from
# 4                   Clothing  Where does it come from
# 5                   Clothing  Where does it come from
# 6                   Clothing  Where does it come from
# 7              Utility items               Recreation
# 8                  Packaging              Agriculture
# 9              Utility items  Where does it come from
# 10             Utility items               Recreation
# 11             Utility items               Recreation
# 12          Personal hygiene          Water Treatment
# 13                 Undefined         Personal hygiene
# 14          Personal hygiene  Where does it come from
# 15                 Packaging           Food and drink
# 16                 Packaging  Where does it come from
# 17             Utility items  Where does it come from
# 18                      Food  Where does it come from
# 19              Construction  Where does it come from
# 20             Utility items  Where does it come from
# 21                   Fishing  Where does it come from
# 22                   Fishing  Where does it come from
# 23                 Undefined  Where does it come from
# 24                 Undefined  Where does it come from
# 25                 Undefined  Where does it come from
# 26             Utility items  Where does it come from
# 27              Construction  Where does it come from
# 28                 Packaging  Where does it come from
# 29                 Packaging           Food and drink
# ..                       ...                      ...
# 230               Recreation  Where does it come from
# 231               Recreation  Where does it come from
# 232                 Clothing  Where does it come from
# 233                  Vehicle  Where does it come from
# 234                  Vehicle  Where does it come from
# 235                  Vehicle  Where does it come from
# 236            Utility items  Where does it come from
# 237                  Fishing  Where does it come from
# 238         Personal hygiene          Water Treatment
# 239                Undefined  Where does it come from
# 240         Personal hygiene  Where does it come from
# 241  Where does it come from  Where does it come from
# 242                  Medical  Where does it come from
# 243                Undefined  Where does it come from
# 244                Packaging  Where does it come from
# 245                Packaging  Where does it come from
# 246                Packaging  Where does it come from
# 247                Packaging  Where does it come from
# 248                  Fishing  Where does it come from
# 249                  Fishing  Where does it come from
# 250                Packaging           Food and drink
# 251            Utility items  Where does it come from
# 252               Recreation  Where does it come from
# 253                Undefined  Where does it come from
# 254                Undefined  Where does it come from
# 255                Undefined  Where does it come from
# 256                Undefined  Where does it come from
# 257                Undefined  Where does it come from
# 258                Undefined  Where does it come from
# 259            Utility items  Where does it come from
#
#                 source_three  parent_code  direct  single_use  micro  \
# 0                       none  Parent code   False       False  False
# 1                       none  Parent code    True       False  False
# 2                       none  Parent code   False       False  False
# 3                       none  Parent code    True       False  False
# 4                       none  Parent code    True       False  False
# 5                       none  Parent code    True       False  False
# 6                       none  Parent code    True       False  False
# 7                       none  Parent code    True       False  False
# 8                       none  Parent code   False       False  False
# 9                       none  Parent code   False       False  False
# 10                      none  Parent code    True       False  False
# 11                      none  Parent code    True       False  False
# 12                      none  Parent code   False       False  False
# 13                      none  Parent code    True       False  False
# 14                      none         G145    True       False  False
# 15                      none  Parent code    True        True  False
# 16                      none  Parent code    True       False  False
# 17                       NaN  Parent code    True       False  False
# 18                      none  Parent code   False       False  False
# 19                      none  Parent code    True       False  False
# 20                       NaN  Parent code    True       False  False
# 21                       NaN  Parent code    True       False  False
# 22                       NaN  Parent code    True       False  False
# 23                      none  Parent code    True       False  False
# 24                       NaN  Parent code    True       False  False
# 25                      none  Parent code    True       False  False
# 26                      none         G210   False       False  False
# 27                      none         G204   False       False  False
# 28                       NaN  Parent code    True       False  False
# 29                      none  Parent code    True        True  False
# ..                       ...          ...     ...         ...    ...
# 230                   Direct  Parent code    True        True  False
# 231                      NaN  Parent code    True       False  False
# 232                      NaN  Parent code    True       False  False
# 233                      NaN  Parent code    True       False  False
# 234                      NaN  Parent code    True       False  False
# 235                      NaN  Parent code    True       False  False
# 236                      NaN  Parent code    True       False  False
# 237                      NaN  Parent code    True       False  False
# 238                     none  Parent code    True        True  False
# 239                      NaN  Parent code    True       False  False
# 240                     none         G134    True        True  False
# 241  Where does it come from  Parent code    True       False  False
# 242                     none  Parent code    True        True  False
# 243                      NaN  Parent code    True       False  False
# 244                      NaN  Parent code    True       False  False
# 245                      NaN  Parent code    True       False  False
# 246                     none  Parent code   False       False  False
# 247                      NaN  Parent code    True       False  False
# 248                      NaN  Parent code    True       False  False
# 249                      NaN  Parent code    True       False  False
# 250                     none  Parent code    True        True  False
# 251                      NaN  Parent code    True       False  False
# 252                      NaN  Parent code    True       False  False
# 253                      NaN  Parent code    True       False  False
# 254                      NaN  Parent code    True       False  False
# 255                      NaN  Parent code    True       False  False
# 256                      NaN  Parent code    True       False  False
# 257                      NaN  Parent code    True       False  False
# 258                      NaN  Parent code    True       False  False
# 259                     none         G170    True       False  False
#
#     ospar_code
# 0         none
# 1          181
# 2          111
# 3           54
# 4         none
# 5           54
# 6           57
# 7         none
# 8           56
# 9           55
# 10        none
# 11        none
# 12         100
# 13          59
# 14          59
# 15          91
# 16          93
# 17         NaN
# 18        none
# 19          94
# 20         NaN
# 21         NaN
# 22         NaN
# 23        none
# 24         NaN
# 25          96
# 26          96
# 27          94
# 28         NaN
# 29          78
# ..         ...
# 230         49
# 231        NaN
# 232        NaN
# 233        NaN
# 234        NaN
# 235        NaN
# 236        NaN
# 237        NaN
# 238         97
# 239        NaN
# 240         53
# 241   Ospar...
# 242        105
# 243        NaN
# 244        NaN
# 245        NaN
# 246         69
# 247        NaN
# 248        NaN
# 249        NaN
# 250         72
# 251        NaN
# 252        NaN
# 253        NaN
# 254        NaN
# 255        NaN
# 256        NaN
# 257        NaN
# 258        NaN
# 259       none
#
# [260 rows x 11 columns]
