# %%
# sys things
import os
import sys
import json
import os

# networks
import requests

# data
import pandas as pd
import numpy as np
import scipy
import math
import seaborn as sns

# %%
import resources.utilities.utility_functions as ut

# %%
a, b, c, d, e =ut.make_local_paths()

# %%
print(a,b,c,d,e)
# Out:
# resources/surveydata resources/locationdata resources/mlwcodedefs resources/geodata output

# %%
pd.read_csv(a+'/OSPAR_ID_DutchEnglish.csv')
# Out:
#                                              ID        Description  \
# 0                          plastic_6_packringen      Six pack ring
# 1                                plastic_tassen                Bag
# 2                 plastic_kleine_plastic_tasjes          Small bag
# 3     plastic_drankflessen_groterdan_halveliter  Bottle (>= 0.5 L)
# 4    plastic_drankflessen_kleinerdan_halveliter   Bottle (< 0.5 L)
# ..                                          ...                ...
# 107                    sanitair_overig_sanitair     Other sanitary
# 108                        medisch_verpakkingen  Medical packaging
# 109                             medisch_spuiten            Syringe
# 110                      medisch_overig_medisch      Other medical
# 111                           granulaat_korrels             Nurdle
#
#           category  OSPAR_ID
# 0          PO soft     1.000
# 1          PO soft     2.000
# 2          PO soft     3.000
# 3              PET     4.100
# ...

# %%
pd.read_csv(a+'/mlw_codes.csv')
# Out:
#      code   material                                      description  \
# 0    G212  Chemicals  Oil nodules or coal fragments -- not from a BBQ
# 1    G213  Chemicals                                     Paraffin wax
# 2    G214  Chemicals                                          Oil/tar
# 3    G135      Cloth              Clothes, footware, headware, gloves
# 4    G136      Cloth                                            Shoes
# ..    ...        ...                                              ...
# 255  G170       Wood                                 Wood (processed)
# 256  G171       Wood                                Other wood < 50cm
# 257  G172       Wood                                Other wood > 50cm
# 258  G173       Wood                                            Other
# 259  G916       Wood                               Pencils and pieces
#
#             source               source_two source_three  parent_code  direct  \
# ...
